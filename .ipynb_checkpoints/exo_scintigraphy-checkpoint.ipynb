# %% [markdown]
# # Quantitative scintigraphy image analysis

# %%
# Import required packages
import numpy as np
import matplotlib.pyplot as plt
import os

#Add this line if you want to inspect the displayed images (coordinates, intensity values etc.)
#%matplotlib notebook

# Import SimpleITK
import SimpleITK as sitk

# Import some interactive IPython widgets
# The interact function (ipywidgets.interact) automatically creates user interface (UI) controls for exploring code and data interactively.
from ipywidgets import interact, interactive, fixed

# Define current working directory
PWD_DIR = os.getcwd()
# Define output data directory
OUTPUT_DIR = os.path.join(PWD_DIR,'output')
# If it doesn't exist, create it
if not os.path.exists(OUTPUT_DIR):
    os.makedirs(OUTPUT_DIR)

# %% [markdown]
# # 1. Cortical renal scintigraphy using <sup>99m</sup>Tc-DMSA

# %% [markdown]
# ## Background
# The renal scintigraphy using <sup>99m</sup>Tc-DMSA constitutes a non-invasive and functional method that is of appreciable interest in the qualitative study of renal parenchyma and the evaluation of the separate renal function.
#
# After <sup>99m</sup>Tc-DMSA is injected intravenously it slowly concentrates in the kidney where it mostly becomes bound to the proximal tubular cells. There is a low extraction efficiency by the kidneys, but 2 or 3 hours following injection there is sufficient uptake to obtain good images of the functioning renal cortex with low background.

# %% [markdown]
# ## Data analysis
# Usually, a percent differential renal function (DRF) is calculated from the posterior view by drawing regions of interest (ROI) around each kidney. A
# background ROI should also be drawn in any nearby non-renal area. The
# position of the background ROI makes very little difference except with very
# poorly functioning kidneys. Counts in the background region are used to
# subtract background counts from each kidney ROI (scaled for the relative
# size of the ROIs).
#
# DRF of each kidney is then calculated from the
# percentage of background subtracted counts in each kidney as follows:
#
# \begin{equation}
# DRF_{right}=100\times \frac{Right\ kidney\ counts -background\ counts}{(Right\ kidney\ counts -background\ counts)+(Left\ kidney\ counts -background\ counts)}
# \end{equation}

# %% [markdown]
# ## Objective
# In the following sections, let's see how to apply a semi-automatic segmentation method on <sup>99m</sup>Tc-DMSA images so as to calculate DRF of each kidney

# %% [markdown]
# ## Pre-processing: data exploration

# %%
# Change directory to folder /data/rein
os.chdir('./data/rein/')

# %%
# Display all files stored in folder /data/rein using os.listdir() function
# Select and display all .dcm files 
whole_list = [file for file in os.listdir()]
dcm_list   = [file for file in os.listdir() if file.endswith(".dcm")]
print("Entire list: ", whole_list)
print("Lis of .dcm files: ", dcm_list)
# Out:
# Entire list:  ['FilesIndex.txt', 'FACEANTERIEURE001_DS.dcm', 'PosteriorStatic001_DS.dcm', 'RightKidney.csv', 'AnteriorStatic001_DS.dcm', 'Background.csv', 'background', 'Rkidney', 'ScreenCapBasicData001_SC.dcm', 'Lkidney', 'LeftKidney.csv']
# Lis of .dcm files:  ['FACEANTERIEURE001_DS.dcm', 'PosteriorStatic001_DS.dcm', 'AnteriorStatic001_DS.dcm', 'ScreenCapBasicData001_SC.dcm']

# %%
# Read the image corresponding to posterior view of 99m DMSA static scintigraphy 
dmsa_post = sitk.ReadImage('PosteriorStatic001_DS.dcm')
# Display image pixel type
print(dmsa_post.GetPixelIDTypeAsString())
# Out:
# 16-bit unsigned integer

# %%
# Import pydicom package for inspecting and modifying DICOM files in an easy pythonic way
import pydicom
from pydicom.tag import Tag
# Read DICOM information 
ds = pydicom.filereader.dcmread('PosteriorStatic001_DS.dcm')

# Print several useful DICOM dataset information 
print("Exam modality: ", ds.Modality)
print("Modality tag:",Tag('Modality'))
 
print("Image attributes - lines/rows (in pixels)")
print(ds[0x0028,0x0010])
print(ds[0x0028,0x0011])
print("Patient information (name, weight)")
print(ds[0x0010,0x0010])
print(ds[0x0008,0x1030])
print("Acquisition information")
print(ds[0x0008,0x1010])
print(ds[0x0008,0x1030])
print(ds[0x0009,0x1010])
print(ds[0x0010,0x1030])
print(ds[0x0010,0x0030])
print(ds[0x0018,0x1242])
print(ds[0x0054,0x0022][0][0x0018,0x1180])
print(ds[0x0054,0x0022][0][0x0018,0x1181])
# If you want to extract and display a specific DICOM tag value 
print("For instance, to only extract the Study Name value: ",ds[0x0009,0x1010].value)
# If you want to print all DICOM tags
#print(ds)
# Out:
# Exam modality:  NM
# Modality tag: (0008, 0060)
# Image attributes - lines/rows (in pixels)
# (0028, 0010) Rows                                US: 128
# (0028, 0011) Columns                             US: 128
# Patient information (name, weight)
# (0010, 0010) Patient's Name                      PN: 'DMSA^ENFANT^^^'
# (0008, 1030) Study Description                   LO: 'REIN DMSA : IMAGES'
# Acquisition information
# (0008, 1010) Station Name                        SH: 'xeleris-med'
# (0008, 1030) Study Description                   LO: 'REIN DMSA : IMAGES'
# (0009, 1010) [Study Name]                        LO: 'DMSA'
# (0010, 1030) Patient's Weight                    DS: "16.0"
# (0010, 0030) Patient's Birth Date                DA: '20160404'
# (0018, 1242) Actual Frame Duration               IS: "240000"
# (0018, 1180) Collimator/grid Name                SH: 'LEHR'
# (0018, 1181) Collimator Type                     CS: 'PARA'
# For instance, to only extract the Study Name value:  DMSA

# %%
# Access to posterior view of 99m DMSA static scintigraphy image attributes using SimpleITK functions
print("Number of pixels: ", dmsa_post.GetNumberOfPixels())
print("Image size: ", dmsa_post.GetSize())
print("Image spacing (voxel size): ", dmsa_post.GetSpacing())
print("Image details: ", dmsa_post.GetWidth(), dmsa_post.GetHeight(), dmsa_post.GetDepth())
print("Image dimensions: ", dmsa_post.GetDimension())
print("Image depth (number of components): ", dmsa_post.GetNumberOfComponentsPerPixel())
# Out:
# Number of pixels:  16384
# Image size:  (128, 128, 1)
# Image spacing (voxel size):  (3.451684, 3.451684, 1.0)
# Image details:  128 128 1
# Image dimensions:  3
# Image depth (number of components):  1

# %%
# Access to posterior view of 99m DMSA static scintigraphy image basic statistics
stats = sitk.StatisticsImageFilter()
stats.Execute(dmsa_post)
print(stats)
# Print only minimum and maximum intensity values
print("Image minimum intensity: ", stats.GetMinimum())
print("Image maximum intensity: ", stats.GetMaximum())
# Out:
# itk::simple::StatisticsImageFilter
#   Minimum: 0
#   Maximum: 552
#   Mean: 15.566
#   Sigma: 51.0739
#   Variance: 2608.54
#   Sum: 255033
#   Debug: 0
#   NumberOfThreads: 8
#   Commands: (none)
#   ProgressMeasurement: 1
#   ActiveProcess: (none)
#
# Image minimum intensity:  0.0
# Image maximum intensity:  552.0

# %%
# Conversion of posterior view image to NumPy array
dmsa_post_arr = sitk.GetArrayFromImage(dmsa_post)
print(dmsa_post_arr.shape)
# Remove the third dimension using reshape function
dmsa_post_arr = dmsa_post_arr.reshape(dmsa_post.GetWidth(),dmsa_post.GetHeight())
print(dmsa_post_arr.shape)
# Out:
# (1, 128, 128)
# (128, 128)

# %%
# Display posterior view image using different color maps
cpt = 1
color_list = ['viridis','jet','binary','gray']
plt.subplots(2, 2, figsize=(10, 10)) # we force a 10x10 size for display
for color in color_list:
    plt.subplot((len(color_list))/2,2,cpt)
    plt.imshow(dmsa_post_arr,cmap=color)
    plt.title(color)
    plt.axis('off')
    cpt+=1

# %%
# Plot the image intensity histogram using different number of bins and range values
plt.subplots(2, 2, figsize=(10, 10))
plt.subplot(2,2,1)

# Hist method computes and draws the histogram of x. 
# The return value is a tuple (n, bins, patches) or ([n0, n1, ...], bins, [patches0, patches1,...]) 
# if the input contains multiple data 
# Flatten method returns a copy of the array collapsed into one dimension
plt.hist(dmsa_post_arr.flatten(),bins=256,range=(stats.GetMinimum(),stats.GetMaximum()))
plt.title("256 bins, range 0-512")
plt.subplot(2,2,2)
plt.hist(dmsa_post_arr.flatten(),256,range=(0,256))
plt.title("256 bins, range 0-256")
plt.subplot(2,2,3)
plt.hist(dmsa_post_arr.flatten(),64,[0,256])
plt.title("64 bins, range 0-256")
plt.subplot(2,2,4)
plt.hist(dmsa_post_arr.flatten(),32,[0,64])
plt.title("32 bins, range 0-64")
plt.suptitle('Histograms',fontsize=20)
plt.tight_layout()
plt.subplots_adjust(top=0.9)

# %%
# Let's see how to perform a basic thresholding of 99m DMSA static scintigraphy image attributes
print("Maximum intensity value in image is",dmsa_post_arr.max(),'\n')

# Based on this previous histogram analysis, apply use 80 as an absolute threshold
dmsa_post_bin_arr = dmsa_post_arr>80
print(dmsa_post_bin_arr)
# dmsa_post_bin_arr only contains booleans (true or false) for each pixel
# for each pixel, dmsa_post_bin_arr answers the question is value > threshold ?
# if value > threshold then condition is true
# if value < threshold then condition is false
# Out:
# Maximum intensity value in image is 552
#
# [[False False False ... False False False]
#  [False False False ... False False False]
#  [False False False ... False False False]
#  ...
#  [False False False ... False False False]
#  [False False False ... False False False]
#  [False False False ... False False False]]

# %%
# We can use plt.imshow because Python considers two intensity values
# One for True and another one for False
plt.imshow(dmsa_post_bin_arr)

# %%
# Overlay of the two images (dmsa_post and its mask corresponding to an absolute threshold of 80)
plt.imshow(dmsa_post_arr)
dmsa_post_bin_arr_mask = np.ma.masked_where(dmsa_post_bin_arr==True, dmsa_post_bin_arr)
plt.imshow(dmsa_post_bin_arr_mask, alpha=0.7)

# %%
# Let's try several absolute threshold values
thresh_abs_list = [20,30,40,50,60,80]
cpt = 1
plt.subplots(2,3,figsize=(15,10))
for thresh_abs in thresh_abs_list:
    plt.subplot(2,3,cpt)
    plt.imshow(dmsa_post_arr>thresh_abs)
    plt.title("threshold value : "+str(thresh_abs))
    plt.axis('off')
    cpt += 1

# %%
# Let's try several relative threshold values
thresh_rel_list = [.05,.1,.3,.5,.6,.8]
cpt = 1
plt.subplots(2,3,figsize=(15,10))
for thresh_rel in thresh_rel_list:
    plt.subplot(2,3,cpt)
    plt.imshow(dmsa_post_arr>(dmsa_post_arr.max()*thresh_rel))
    plt.title("Relative threshold: "+str(thresh_rel))
    plt.axis('off')
    cpt += 1

# %%
# Source image to be processed: dmsa_post (SimpleITK image) or dmsa_post_arr (NumPy array)
# We apply a mask corresponding to the thresholding binarisation previously obtained
# Arbitrarily, we'll take a relative threshold value of 50% maximum image intensity value
thresh50 = 0.5 * dmsa_post_arr.max()
mask50 = (dmsa_post_arr > thresh50) 
dmsa_post50 = dmsa_post_arr * mask50 # set each pixel outside the mask to zero (because False)
plt.subplots(figsize=(10,10))
plt.subplot(211)
plt.imshow(mask50)
plt.subplot(212)
plt.imshow(dmsa_post50)

# %%
# Apply this mask for different relative threshold values but now keep the intensity values
# Let's try several relative threshold values
thresh_rel_list=[.05,.1,.2,.3,.5,.7]
cpt = 1
plt.subplots(2,3,figsize=(15,10))
for thresh_rel in thresh_rel_list:
    plt.subplot(2,3,cpt)
    plt.imshow(dmsa_post_arr*(dmsa_post_arr>(dmsa_post_arr.max()*thresh_rel)))
    plt.title("Relative threshold: "+str(thresh_rel))
    plt.axis('off')
    cpt+=1

# %% [markdown]
# Based on this data exploration step, a relative threshold of 20% seems to be a good value to perform a semi-automatic segmentation of each kidney

# %% [markdown]
# ## Quantitative analysis

# %% [markdown]
# ### First step
#
# We can divide the image in two along horizontal direction (using a vertical separation...)
#
# Hence, we obtain two posterior views of <sup>99m</sup>Tc DMSA scintigraphy images, one for right kidney and another one for left kidney

# %%
width_dmsa = dmsa_post.GetWidth()

Lkidney = dmsa_post_arr[:,0:int(width_dmsa/2)]
Rkidney = dmsa_post_arr[:,int(width_dmsa/2):width_dmsa]

plt.subplots(1,2,figsize=(5,5))
plt.subplot(1,2,1)
plt.imshow(Lkidney)
plt.subplot(1,2,2)
plt.imshow(Rkidney)

# %% [markdown]
# ### Second step (method 1)
# Quantitative analysis in each ROI (Right and Left) using [SciPy](www.scipy.org) (sorry, this package should have been presented during the lesson) and Pandas packages

# %%
# We define approriate thresholds
# 20% for kidneys
thresh20 = 0.2 * dmsa_post_arr.max()
mask20R = Rkidney > thresh20
mask20L = Lkidney > thresh20
# Between 5 and 20 % for background around kidneys
thresh5 = 0.05 * dmsa_post_arr.max()
mask5 = (dmsa_post_arr >= thresh5) & (dmsa_post_arr <= thresh20)

# %%
# Segmentation and measurements performed using the submodule ndimage from Scipy package
from scipy import ndimage
import pandas as pd

def show_stats(mask,img,file):
    # Compute size, mean_value, etc. of each region
    label_im, nb_labels = ndimage.label(mask)
    label_sizes=ndimage.sum(mask, label_im, range(nb_labels + 1))
    # Clean up small connect components (in terms of size) -- required for background
    new_label_sizes = label_sizes[label_sizes > 10]
    #print(new_label_sizes)
    # Clean up small connect components (in terms of number of labels) -- required for background
    mask_label_sizes = label_sizes <= 10
    remove_pixel = mask_label_sizes[label_im]
    label_im[remove_pixel] = 0
    labels = np.unique(label_im)
    label_im = np.searchsorted(labels, label_im)
    
    print("Number of labels before cleaning:", nb_labels)
    print("Number of labels after cleaning:", (len(labels)-1))
    
    stats_list={"Volume (mm^3)": new_label_sizes*dmsa_post.GetSpacing()[0]*dmsa_post.GetSpacing()[1]*dmsa_post.GetSpacing()[2],
                "Volume (number of pixels)": new_label_sizes,
                "Intensity mean": ndimage.mean(img, label_im, range(1, len(labels))),
                "Intensity standard deviation": ndimage.standard_deviation(img, label_im, range(1, len(labels))),
                "Intensity max": ndimage.maximum(img, label_im, range(1, len(labels))),
                "Intensity min": ndimage.minimum(img, label_im, range(1, len(labels))),
                "Intensity median": ndimage.median(img, label_im, range(1, len(labels))),
                }
    # stats_list is a dictionary
    stats=pd.DataFrame(stats_list, index=range(1, len(labels)))
    stats.to_csv(file, sep='\t')
    return stats

# %%
interact(show_stats, mask=fixed(mask5), img=fixed(dmsa_post_arr), file='Background.csv');
# Out:
# interactive(children=(Text(value='Background.csv', description='file'), Output()), _dom_classes=('widget-inter…

# %%
interact(show_stats, mask=fixed(mask20L), img=fixed(Lkidney), file='LeftKidney.csv');
# Out:
# interactive(children=(Text(value='LeftKidney.csv', description='file'), Output()), _dom_classes=('widget-inter…

# %%
interact(show_stats, mask=fixed(mask20R), img=fixed(Rkidney), file='RightKidney.csv');
# Out:
# interactive(children=(Text(value='RightKidney.csv', description='file'), Output()), _dom_classes=('widget-inte…

# %% [markdown]
# ### Second step (method 2)
# Quantitative analysis in each ROI (Right and Left) using SimpleITK and Pandas packages

# %%
imgLkidney = sitk.GetImageFromArray(Lkidney)
imgLkidney.SetSpacing([dmsa_post.GetSpacing()[0], dmsa_post.GetSpacing()[1],1])
imgRkidney = sitk.GetImageFromArray(Rkidney)
imgRkidney.SetSpacing([dmsa_post.GetSpacing()[0], dmsa_post.GetSpacing()[1],1])
imgTotal = sitk.GetImageFromArray(dmsa_post_arr)
imgTotal.SetSpacing([dmsa_post.GetSpacing()[0], dmsa_post.GetSpacing()[1],1])

# Let's use 20% as a relative threshold to semi-automatically draw ROI around each kidney and 5% for background ROI
thresh20 = 0.2 * dmsa_post_arr.max()
thresh5 = 0.05 * dmsa_post_arr.max()
segL = sitk.BinaryThreshold(imgLkidney, upperThreshold=thresh20, insideValue=0, outsideValue=1)
segR = sitk.BinaryThreshold(imgRkidney, upperThreshold=thresh20, insideValue=0, outsideValue=1)
segback = sitk.BinaryThreshold(imgTotal, lowerThreshold=thresh5, upperThreshold=thresh20, insideValue=1, outsideValue=0)
sitk.WriteImage(segback, os.path.join(OUTPUT_DIR, 'mask5-2.nii'))

# LabelIntensityStatisticsImageFilter is a convenient class to convert a label image to a label map and valuate the statistics attributes at once
intensity_stats = sitk.LabelIntensityStatisticsImageFilter()

# Home-made function to compute and display standard statistics derived from a specific ROI
def show_stats2(seg,img,file):
    intensity_stats=sitk.LabelIntensityStatisticsImageFilter()
    intensity_stats.Execute(seg,img)
    for i in intensity_stats.GetLabels():
        #print(intensity_stats.GetMean(i), intensity_stats.GetPhysicalSize(i))
        stats_list={"Volume (mm^3)": intensity_stats.GetPhysicalSize(i),
                    "Volume (number of pixels)": intensity_stats.GetNumberOfPixels(i),
                    "Intensity mean": intensity_stats.GetMean(i),
                    "Intensity standard deviation": intensity_stats.GetStandardDeviation(i),
                    "Intensity max": intensity_stats.GetMaximum(i),
                    "Intensity min": intensity_stats.GetMinimum(i),
                    "Intensity median": intensity_stats.GetMedian(i),
                    }
    # stats_list is a dictionary
    stats=pd.DataFrame(stats_list, index=[intensity_stats.GetLabels()[0]])
    stats.to_csv(file, sep='\t')
    return stats

# %%
# Show stats in left kidney
interact(show_stats2, seg=fixed(segL), img=fixed(imgLkidney), file='Lkidney');
# Out:
# interactive(children=(Text(value='Lkidney', description='file'), Output()), _dom_classes=('widget-interact',))

# %%
# Show stats in right kidney
interact(show_stats2, seg=fixed(segR), img=fixed(imgRkidney), file='Rkidney');
# Out:
# interactive(children=(Text(value='Rkidney', description='file'), Output()), _dom_classes=('widget-interact',))

# %%
# Show stats in background
interact(show_stats2, seg=fixed(segback), img=fixed(imgTotal), file='background');
# Out:
# interactive(children=(Text(value='background', description='file'), Output()), _dom_classes=('widget-interact'…

# %% [markdown]
# Now, we can derive from the above-displayed image statistics DRF of each kidney and check we obtain values between 45% and 55%, range representative of a normal renal function.

# %%
dfL=pd.read_csv("LeftKidney.csv", sep='\t')
dfR=pd.read_csv("RightKidney.csv", sep='\t')
dfB=pd.read_csv("Background.csv", sep='\t')
DRFL=float(100*((dfL["Intensity mean"]-dfB["Intensity mean"])/(dfL["Intensity mean"]-dfB["Intensity mean"]+dfR["Intensity mean"]-dfB["Intensity mean"])))
print("DRF of left kidney: {:0.2f}%".format(DRFL))
DRFR=float(100*((dfR["Intensity mean"]-dfB["Intensity mean"])/(dfL["Intensity mean"]-dfB["Intensity mean"]+dfR["Intensity mean"]-dfB["Intensity mean"])))
print("DRF of right kidney: {:0.2f}%".format(DRFR))
# Out:
# DRF of left kidney: 46.48%
# DRF of right kidney: 53.52%

# %% [markdown]
# A mentioned in the Renal Cortical Scintigraphy (DMSA scan) Clinical Guidelines published by the British nuclear medicine society, if an anterior view has also been obtained, background subtracted kidney
# counts should also be calculated from this image. The geometric mean of
# the posterior and anterior background subtracted counts in each kidney
# should then be calculated.
# \begin{equation}
# Geometric\ Mean\ Count = \sqrt {Posterior\ Count \times Anterior Count}
# \end{equation}
# The geometric mean DRF should be calculated using these geometric mean
# counts. This gives an approximate correction for the fact that kidneys may lie
# at different depths. It is particularly important for ectopic or malrotated
# kidneys.

# %% [markdown]
# # 2. <sup>99m</sup>Tc-sestamibi and iodine 123 parathyroid scintigraphy2.

# %% [markdown]
# ## Background
# <sup>99m</sup>Tc-sestamibi is an isonitrile radionuclide imaging agent that, when used with subtraction iodine 123 thyroid scans, has the potential for imaging abnormal parathyroid glands.
#
# Sodium iodine 123 is administered intravenously, followed 2 hours later by <sup>99m</sup>Tc-sestamibi. The patient is then positioned for imaging. The distribution images of <sup>99m</sup>Tc-sestamibi and <sup>123</sup>I are simultaneously recorded. Three to 5 minutes after <sup>99m</sup>Tc-sestamibi injection, an anterior view of the neck and mediastinum is acquired for 5 minutes to detect any ectopic uptake, from the angle of the mandible to the heart. The parallel-holes collimator is then replaced by a pinhole collimator and an anterior view of the thyroid region was obtained for 10 minutes. The <sup>123</sup>I image is subtracted from the <sup>99m</sup>Tc-sestamibi image.
#
# Given there will be more counts in the thyroid on the <sup>123</sup>I image, it must be matched to the <sup>99m</sup>Tc image before subtraction and a scaling factor is used so that the counts in the subtraction image are reduced by this factor, pixel by pixel.  The scaling factor is calculated
# from the ratio of these two values. This adjusted
# image is then subtracted from the 99mTc image
# and the results displayed as a new image.

# %%
# Change directory to /data/para
os.chdir('../../data/para')

# %% [markdown]
# ## Pre-processing: data exploration

# %%
# Display all files stored in folder /data/para
liste_complete = [file for file in os.listdir()]
liste_dcm      = [file for file in os.listdir() if file.endswith(".dcm")]
print("Entire list: ",liste_complete)
print("Lis of .dcm files: ",liste_dcm)
# Out:
# Entire list:  ['ArithResultImage003_DS.dcm', 'FilesIndex.txt', 'mibi2.png', 'PINHOLE_Tc99m001_DS.dcm', 'Parathyroid001_DS.dcm', 'Thyroid001_DS.dcm', 'ScreenCapDualTracerProcessing001_SC.dcm', 'RotatedImage001_DS.dcm', 'mibi.png', 'ArithResultImage001_DS.dcm', 'ArithResultImage002_DS.dcm']
# Lis of .dcm files:  ['ArithResultImage003_DS.dcm', 'PINHOLE_Tc99m001_DS.dcm', 'Parathyroid001_DS.dcm', 'Thyroid001_DS.dcm', 'ScreenCapDualTracerProcessing001_SC.dcm', 'RotatedImage001_DS.dcm', 'ArithResultImage001_DS.dcm', 'ArithResultImage002_DS.dcm']

# %%
# Read and display image PINHOLE_Tc99m001_DS.dcm
para_dual=sitk.ReadImage('PINHOLE_Tc99m001_DS.dcm')
para_dual_arr=sitk.GetArrayFromImage(para_dual)
print(para_dual_arr.shape)
plt.subplots(1,2, figsize=(10,10))
plt.subplot(1,2,1)
plt.imshow(para_dual_arr[0])
plt.axis('off')
plt.subplot(1,2,2)
plt.imshow(para_dual_arr[1])
plt.axis('off')
plt.savefig("mibi.png", dpi=300)
# Out:
# (2, 128, 128)

# %%
# Read DICOM information
ds=pydicom.filereader.dcmread('PINHOLE_Tc99m001_DS.dcm')

# Print several useful DICOM dataset information 
print("Exam modality: ", ds.Modality)
print("Image attributes - lines/rows (in pixels)")
print (ds[0x0028,0x0010])
print (ds[0x0028,0x0011])
print("Patient information (name, weight)")
print (ds[0x0010,0x0010])
print (ds[0x0008,0x1030])
print("Acquisition information")
print (ds[0x0008,0x1010])
print (ds[0x0008,0x1030])
print (ds[0x0009,0x1010])
print (ds[0x0010,0x1030])
print (ds[0x0010,0x0030])
print(ds[0x0018,0x1242])
print(ds[0x0054,0x0022][0][0x0018,0x1180])
print(ds[0x0054,0x0022][0][0x0018,0x1181])
# If you want to extract and display a specific DICOM tag value 
print("For instance, to only extract the Study Name value: ",ds[0x0009,0x1010].value)
# Print all DICOM tags
print(ds)
# Out:
# Exam modality:  NM
# Image attributes - lines/rows (in pixels)
# (0028, 0010) Rows                                US: 128
# (0028, 0011) Columns                             US: 128
# Patient information (name, weight)
# (0010, 0010) Patient's Name                      PN: 'PARATHYROIDE^FEMME^^^'
# (0008, 1030) Study Description                   LO: 'PARATHYROIDES DOUBLE ISOTOPES : IMAGES'
# Acquisition information
# (0008, 1010) Station Name                        SH: 'INFINIA'
# (0008, 1030) Study Description                   LO: 'PARATHYROIDES DOUBLE ISOTOPES : IMAGES'
# (0009, 1010) [Study Name]                        LO: 'Parathyroide Pin'
# (0010, 1030) Patient's Weight                    DS: "78.0"
# (0010, 0030) Patient's Birth Date                DA: '19430101'
# (0018, 1242) Actual Frame Duration               IS: "600000"
# (0018, 1180) Collimator/grid Name                SH: 'PIN-HOLE'
# (0018, 1181) Collimator Type                     CS: 'PINH'
# For instance, to only extract the Study Name value:  Parathyroide Pin
# Dataset.file_meta -------------------------------
# (0002, 0000) File Meta Information Group Length  UL: 204
# (0002, 0001) File Meta Information Version       OB: b'\x00\x01'
# (0002, 0002) Media Storage SOP Class UID         UI: Nuclear Medicine Image Storage
# (0002, 0003) Media Storage SOP Instance UID      UI: 1.2.840.113619.2.265.1.2.0.5032019092429796.13947
# (0002, 0010) Transfer Syntax UID                 UI: Explicit VR Little Endian
# (0002, 0012) Implementation Class UID            UI: 1.2.840.113619.6.184
# (0002, 0013) Implementation Version Name         SH: 'Xeleris 2.1753'
# (0002, 0016) Source Application Entity Title     AE: 'XELERIS-MED'
# -------------------------------------------------
# (0008, 0000) Group Length                        UL: 530
# (0008, 0008) Image Type                          CS: ['ORIGINAL', 'PRIMARY', 'STATIC', 'EMISSION']
# (0008, 0012) Instance Creation Date              DA: '20190402'
# (0008, 0013) Instance Creation Time              TM: '101007.0000'
# (0008, 0014) Instance Creator UID                UI: 1.2.840.113619.6.184
# (0008, 0016) SOP Class UID                       UI: Nuclear Medicine Image Storage
# (0008, 0018) SOP Instance UID                    UI: 1.2.840.113619.2.265.1.2.0.5032019092429796.13947
# (0008, 0020) Study Date                          DA: '20190305'
# (0008, 0021) Series Date                         DA: '20190305'
# (0008, 0022) Acquisition Date                    DA: '20190305'
# (0008, 0023) Content Date                        DA: '20190305'
# (0008, 0030) Study Time                          TM: '102548.00'
# (0008, 0031) Series Time                         TM: '102548.00'
# (0008, 0032) Acquisition Time                    TM: '102548.00'
# (0008, 0033) Content Time                        TM: '102548.00'
# (0008, 0050) Accession Number                    SH: 'A93654775887'
# (0008, 0060) Modality                            CS: 'NM'
# (0008, 0070) Manufacturer                        LO: 'GE MEDICAL SYSTEMS'
# (0008, 0080) Institution Name                    LO: 'CHU Hautepierre'
# (0008, 0090) Referring Physician's Name          PN: ''
# (0008, 1010) Station Name                        SH: 'INFINIA'
# (0008, 1030) Study Description                   LO: 'PARATHYROIDES DOUBLE ISOTOPES : IMAGES'
# (0008, 103e) Series Description                  LO: 'PINHOLE'
# (0008, 1060) Name of Physician(s) Reading Study  PN: ''
# (0008, 1070) Operators' Name                     PN: ''
# (0008, 1090) Manufacturer's Model Name           LO: 'INFINIA'
# (0009, 0000) Private Creator                     UL: 320
# (0009, 0010) Private tag data                    LO: 'GEMS_GENIE_1'
# (0009, 1001) [Unknown]                           SH: 'GEMS_GENIE'
# (0009, 1010) [Study Name]                        LO: 'Parathyroide Pin'
# (0009, 1011) [Study Flags]                       SL: 4097
# (0009, 1012) [Study Type]                        SL: 0
# (0009, 101e) [Dataset UID]                       UI: ''
# (0009, 1020) [Series Object Name]                LO: 'PINHOLE'
# (0009, 1021) [Series Flags]                      SL: 1
# (0009, 1022) [User Orientation]                  SH: ''
# (0009, 1023) [Initiation Type]                   SL: 0
# (0009, 1024) [Initiation Delay]                  SL: 0
# (0009, 1025) [Initiation Count Rate]             SL: 0
# (0009, 1026) [Number Energy Sets]                SL: 2
# (0009, 1027) [Number Detectors]                  SL: 1
# (0009, 1028) [Number RR Windows]                 SL: 0
# (0009, 1029) [Number MG Time Slots]              SL: 0
# (0009, 102a) [Number View Sets]                  SL: 0
# (0009, 102b) [Trigger History UID]               LO: ''
# (0009, 102c) [Series Comments]                   LO: ''
# (0009, 102e) [Distance Prescribed]               FD: 0.0
# (0009, 102f) [Table Direction]                   SL: 0
# (0009, 1040) [Patient Object Name]               PN: ''
# (0009, 1041) [Patient Flags]                     SL: 1
# (0009, 1042) [Patient Creation Date]             DA: ''
# (0009, 1043) [Patient Creation Time]             TM: ''
# (0009, 1045) [Unknown]                           LT: '**\\**'
# (0010, 0000) Group Length                        UL: 124
# (0010, 0010) Patient's Name                      PN: 'PARATHYROIDE^FEMME^^^'
# (0010, 0020) Patient ID                          LO: '1967345'
# (0010, 0030) Patient's Birth Date                DA: '19430101'
# (0010, 0040) Patient's Sex                       CS: 'F'
# (0010, 1000) Other Patient IDs                   LO: ''
# (0010, 1001) Other Patient Names                 PN: ''
# (0010, 1020) Patient's Size                      DS: "0.0"
# (0010, 1030) Patient's Weight                    DS: "78.0"
# (0010, 2160) Ethnic Group                        SH: ''
# (0010, 2180) Occupation                          SH: ''
# (0011, 0000) Private Creator                     UL: 936
# (0011, 0010) Private tag data                    LO: 'GEMS_GENIE_1'
# (0011, 100a) [Series Type]                       SL: 0
# (0011, 100b) [Effective Series Duration]         SL: 0
# (0011, 100c) [Num Beats]                         SL: 0
# (0011, 100d) [Radio Nuclide Name]                LO: 'Tc99m+I123[140 and 159]'
# (0011, 1010) [Dataset Object Name]               LO: ''
# (0011, 1011) [Dataset Modified]                  SL: [0, 0]
# (0011, 1012) [Dataset Name]                      LO: ['PINHOLE_Tc99m', 'PINHOLE_I123']
# (0011, 1013) [Dataset Type]                      SL: 0
# (0011, 1014) [Completion Time]                   LO: ''
# (0011, 1015) [Detector Number]                   SL: [1, 1]
# (0011, 1016) [Energy Number]                     SL: [1, 2]
# (0011, 1017) [RR Interval Window Number]         SL: [0, 0]
# (0011, 1018) [MG Bin Number]                     SL: [0, 0]
# (0011, 1019) [Radius Of Rotation]                FD: [0.0, 0.0]
# (0011, 101a) [Detector Count Zone]               SL: [0, 0]
# (0011, 101f) [Image Orientation]                 SL: [0, 0]
# (0011, 1026) [Table Orientation]                 SL: [0, 0]
# (0011, 1027) [ROI Top Left]                      SL: [0, 0, 0, 0]
# (0011, 1028) [ROI Bottom Right]                  SL: [0, 0, 0, 0]
# (0011, 102c) [View X Adjustment]                 FD: [0.0, 0.0]
# (0011, 102d) [View Y Adjustment]                 FD: [0.0, 0.0]
# (0011, 102e) [Pixel Overflow Flag]               SL: [0, 0]
# (0011, 102f) [Overflow Level]                    SL: [32767, 32767]
# (0011, 1030) [Picture Object Name]               LO: ['PINHOLE_Tc99m', 'PINHOLE_I123']
# (0011, 1031) [Acquisition Parent UID]            LO: ['', '**']
# (0011, 1032) [Processing Parent UID]             LO: ['**', '**']
# (0011, 1033) [Energy Correct Name]               LO: ['**', '**']
# (0011, 1034) [Spatial Correct Name]              LO: ['', '**']
# (0011, 1035) [Tuning Calib Name]                 LO: ['**', '**']
# (0011, 1036) [Uniformity Correct Name]           LO: ['**', '**']
# (0011, 1037) [Acquisition Specific Correction Na LT: '**\\**'
# (0011, 1038) [Byte Order]                        SL: [108, 108]
# (0011, 1039) [Compression Type]                  SL: [0, 0]
# (0011, 103a) [Picture Format]                    SL: [0, 0]
# (0011, 103b) [Pixel Scale]                       FD: [1.0, 1.0]
# (0011, 103c) [Pixel Offset]                      FD: [0.0, 0.0]
# (0011, 103f) [Dataset Flags]                     SL: [257, 257]
# (0011, 1040) [Viewing Object Name]               LO: ['current', 'current']
# (0011, 1041) [Orientation Angle]                 SL: [0, 0]
# (0011, 1042) [Rotation Angle]                    FD: [0.0, 0.0]
# (0011, 1043) [Window Inverse Flag]               SL: [0, 0]
# (0011, 1044) [Threshold Center]                  FD: [2048.0, 2048.0]
# (0011, 1045) [Threshold Width]                   FD: [4096.0, 4096.0]
# (0011, 1046) [Interpolation Type]                SL: [2, 2]
# (0011, 1050) [Where Object Name]                 LO: ['PINHOLE_Tc99m', 'PINHOLE_I123']
# (0011, 1055) [Period]                            FD: [1.0, 1.0]
# (0011, 1056) [Elapsed Time]                      FD: [1.0, 1.0]
# (0011, 1057) [FOV]                               FD: [282.761984, 282.761984, 282.761984, 282.761984]
# (0013, 0000) Private Creator                     UL: 112
# (0013, 0010) Private tag data                    LO: 'GEMS_GENIE_1'
# (0013, 1010) [Digital FOV]                       FD: [0.0, 0.0, 0.0, 0.0]
# (0013, 1011) [Source Translator]                 SL: 4
# (0013, 1012) [RAL Flags]                         SL: [0, 0]
# (0013, 1015) [Fscalar]                           FD: [0.0, 0.0]
# (0018, 0000) Group Length                        UL: 176
# (0018, 0015) Body Part Examined                  CS: 'CHEST'
# (0018, 0070) Counts Accumulated                  IS: "297614"
# (0018, 0071) Acquisition Termination Condition   CS: 'TIME'
# (0018, 1000) Device Serial Number                LO: '17325'
# (0018, 1020) Software Versions                   LO: '2.105.030.18'
# (0018, 1030) Protocol Name                       LO: 'CrystalThickness 5'
# (0018, 1061) Trigger Source or Type              LO: 'EKG'
# (0018, 1130) Table Height                        DS: "0.0"
# (0018, 1131) Table Traverse                      DS: "2136.48"
# (0018, 1242) Actual Frame Duration               IS: "600000"
# (0018, 1243) Count Rate                          IS: "1096"
# (0018, 5100) Patient Position                    CS: 'FFS'
# (0020, 0000) Group Length                        UL: 218
# (0020, 000d) Study Instance UID                  UI: 2.16.840.1.113669.632.20.670001.900002366182
# (0020, 000e) Series Instance UID                 UI: 1.2.840.113619.2.265.1.2.0.5032019092430015.13666
# (0020, 0010) Study ID                            SH: 'Parathyroide Pin'
# (0020, 0011) Series Number                       IS: "1"
# (0020, 0013) Instance Number                     IS: None
# (0020, 0052) Frame of Reference UID              UI: 1.2.840.113619.2.265.1.2.0.5032019092430015.13666
# (0020, 1040) Position Reference Indicator        LO: ''
# (0028, 0000) Group Length                        UL: 198
# (0028, 0002) Samples per Pixel                   US: 1
# (0028, 0004) Photometric Interpretation          CS: 'MONOCHROME2'
# (0028, 0008) Number of Frames                    IS: "2"
# (0028, 0009) Frame Increment Pointer             AT: [(0054, 0010), (0054, 0020)]
# (0028, 0010) Rows                                US: 128
# (0028, 0011) Columns                             US: 128
# (0028, 0030) Pixel Spacing                       DS: [2.209078, 2.209078]
# (0028, 0100) Bits Allocated                      US: 16
# (0028, 0101) Bits Stored                         US: 16
# (0028, 0102) High Bit                            US: 15
# (0028, 0103) Pixel Representation                US: 0
# (0028, 0106) Smallest Image Pixel Value          US: 0
# (0028, 0107) Largest Image Pixel Value           US: 174
# (0028, 1050) Window Center                       DS: "87.0"
# (0028, 1051) Window Width                        DS: "174.0"
# (0033, 0000) Private Creator                     UL: 136
# (0033, 0010) Private tag data                    LO: 'GEMS_GENIE_1'
# (0033, 1007) [Orig SOP Instance UID]             LO: ['1.2.840.113619.2.265.1.2.0.5032019092429796.13947', '1.2.840.113619.2.184.21753.172177051.1551779293.270442100']
# (0040, 0000) Group Length                        UL: 124
# (0040, 0253) Performed Procedure Step ID         SH: 'WLPID_3727665344'
# (0040, 0275)  Request Attributes Sequence   1 item(s) ----
#    (0040, 0007) Scheduled Procedure Step Descriptio LO: 'PARATHYROIDE DOUBLE ISOTOPE : I'
#    (0040, 0009) Scheduled Procedure Step ID         SH: 'A93727665344'
#    (0040, 1001) Requested Procedure ID              SH: 'A93727665344'
#    ---------
# (0054, 0000) Group Length                        UL: 512
# (0054, 0010) Energy Window Vector                US: [1, 2]
# (0054, 0011) Number of Energy Windows            US: 2
# (0054, 0012)  Energy Window Information Sequence   2 item(s) ----
#    (0054, 0013)  Energy Window Range Sequence   1 item(s) ----
#       (0054, 0014) Energy Window Lower Limit           DS: "133.0"
#       (0054, 0015) Energy Window Upper Limit           DS: "147.0"
#       ---------
#    ---------
#    (0054, 0013)  Energy Window Range Sequence   1 item(s) ----
#       (0054, 0014) Energy Window Lower Limit           DS: "151.05"
#       (0054, 0015) Energy Window Upper Limit           DS: "166.95"
#       ---------
#    ---------
# (0054, 0016)  Radiopharmaceutical Information Sequence   1 item(s) ----
#    (0018, 1071) Radiopharmaceutical Volume          DS: "0.0"
#    (0018, 1074) Radionuclide Total Dose             DS: "0.0"
#    (0054, 0300)  Radionuclide Code Sequence   0 item(s) ----
#    ---------
# (0054, 0020) Detector Vector                     US: [1, 1]
# (0054, 0021) Number of Detectors                 US: 1
# (0054, 0022)  Detector Information Sequence   1 item(s) ----
#    (0018, 1120) Gantry/Detector Tilt                DS: "0.0"
#    (0018, 1142) Radial Position                     DS: "0.0"
#    (0018, 1145) Center of Rotation Offset           DS: "0.0"
#    (0018, 1147) Field of View Shape                 CS: ''
#    (0018, 1149) Field of View Dimension(s)          IS: [0, 0]
#    (0018, 1180) Collimator/grid Name                SH: 'PIN-HOLE'
#    (0018, 1181) Collimator Type                     CS: 'PINH'
#    (0018, 1182) Focal Distance                      IS: "0"
#    (0018, 1183) X Focus Center                      DS: "0.0"
#    (0018, 1184) Y Focus Center                      DS: "0.0"
#    (0020, 0032) Image Position (Patient)            DS: [-140.276453, -140.276453, 2136.476453]
#    (0020, 0037) Image Orientation (Patient)         DS: None
#    (0028, 0031) Zoom Factor                         DS: [2.000000, 2.000000]
#    (0028, 0032) Zoom Center                         DS: [0.000000, 0.000000]
#    (0054, 0200) Start Angle                         DS: "180.0"
#    ---------
# (0054, 0400) Image ID                            SH: 'PINHOLE'
# (0054, 0410)  Patient Orientation Code Sequence   0 item(s) ----
# (0054, 0414)  Patient Gantry Relationship Code Sequence   0 item(s) ----
# (0055, 0000) Private Creator                     UL: 536
# (0055, 0010) Private tag data                    LO: 'GEMS_GENIE_1'
# (0055, 1012)  [Xeleris Energy Window Information Sequence]   2 item(s) ----
#    (0055, 0010) Private Creator                     LO: 'GEMS_GENIE_1'
#    (0055, 1013)  [Xeleris Energy Window Range Sequence]   1 item(s) ----
#       (0011, 0010) Private Creator                     LO: 'GEMS_GENIE_1'
#       (0011, 101c) [Energy Offset]                     SL: 0
#       (0011, 101d) [Energy Range]                      SL: 0
#       (0013, 0010) Private Creator                     LO: 'GEMS_GENIE_1'
#       (0013, 1016) [AutoTrack Peak]                    SL: 0
#       (0013, 1017) [AutoTrack Width]                   SL: 0
#       ---------
#    ---------
#    (0055, 0010) Private Creator                     LO: 'GEMS_GENIE_1'
#    (0055, 1013)  [Xeleris Energy Window Range Sequence]   1 item(s) ----
#       (0011, 0010) Private Creator                     LO: 'GEMS_GENIE_1'
#       (0011, 101c) [Energy Offset]                     SL: 0
#       (0011, 101d) [Energy Range]                      SL: 0
#       (0013, 0010) Private Creator                     LO: 'GEMS_GENIE_1'
#       (0013, 1016) [AutoTrack Peak]                    SL: 0
#       (0013, 1017) [AutoTrack Width]                   SL: 0
#       ---------
#    ---------
# (0055, 1022)  [Xeleris Detector Information Sequence]   1 item(s) ----
#    (0011, 0010) Private Creator                     LO: 'GEMS_GENIE_1'
#    (0011, 1023) [Use FOV Mask]                      SL: 0
#    (0011, 1024) [FOV Mask Y Cutoff Distance]        SL: 0
#    (0011, 1025) [FOV Mask Cutoff Angle]             SL: 0
#    (0011, 1029) [Uniformity Mean]                   SL: 0
#    (0011, 103e) [FOV Shape]                         SL: 13
#    (0013, 0010) Private Creator                     LO: 'GEMS_GENIE_1'
#    (0013, 1018) [Transmission Scan Time]            FD: 0.0
#    (0013, 1019) [Transmission Mask Width]           FD: 0.0
#    (0013, 101a) [Copper Attenuator Thickness]       FD: 0.0
#    (0035, 0010) Private Creator                     LO: 'GEMS_GENIE_1'
#    (0035, 1001) [Start Angle]                       FD: 0.0
#    ---------
# (0055, 1065)  [Unknown]   2 item(s) ----
#
#    ---------
#
#    ---------
# (7fe0, 0000) Group Length                        UL: 65548
# (7fe0, 0010) Pixel Data                          OW: Array of 65536 elements

# %%
# Image attributes
print("Number of pixels: ",para_dual.GetNumberOfPixels())
print("Image size: ",para_dual.GetSize())
print("Image spacing (voxel size): ",para_dual.GetSpacing())
print("Image details: ",para_dual.GetWidth(),para_dual.GetHeight(),para_dual.GetDepth())
print("Image dimensions: ",para_dual.GetDimension())
print("Image depth (number of components): ",para_dual.GetNumberOfComponentsPerPixel())
# Out:
# Number of pixels:  32768
# Image size:  (128, 128, 2)
# Image spacing (voxel size):  (2.209078, 2.209078, 1.0)
# Image details:  128 128 2
# Image dimensions:  3
# Image depth (number of components):  1

# %%
# Specific but important other image attributes
print("Number of energy windows: ",ds.NumberOfEnergyWindows)
print("IMPORTANT: according to the following tag ")
print(ds[0x0011,0x100d])
print("the first image corresponds to the first tracer marked with 99mTc (MIBI-Tc)")
print("the second tracer is iodine-123")
# Out:
# Number of energy windows:  2
# IMPORTANT: according to the following tag
# (0011, 100d) [Radio Nuclide Name]                LO: 'Tc99m+I123[140 and 159]'
# the first image corresponds to the first tracer marked with 99mTc (MIBI-Tc)
# the second tracer is iodine-123

# %% [markdown]
# ## Using of dual-isotope subtraction method

# %% [markdown]
# ### First step: separation of the 2 images

# %%
# Using of dual-isotope subtraction method
print(sitk.GetArrayFromImage(para_dual).shape)
para_t1 = sitk.GetArrayFromImage(para_dual)[0]
para_t2 = sitk.GetArrayFromImage(para_dual)[1]
#para_t1 = para_t1.reshape(256,256)
# Out:
# (2, 128, 128)

# %%
plt.subplots(2,2,figsize=(10,10))
plt.subplot(2,2,1)
plt.title("MIBI-Tc99m")
plt.imshow(para_t1,aspect='auto')
plt.axis('off')
plt.subplot(2,2,2)
plt.imshow(para_t2,aspect='auto')
plt.axis('off')
plt.title("Iode 123")
plt.subplot(2,2,3)
plt.hist(para_t1.flatten(),200,[0,200]); plt.show
plt.subplot(2,2,4)
plt.hist(para_t2.flatten(),200,[0,200]); plt.show
plt.savefig('mibi.png', dpi=300, transparent=True, bbox_inches='tight')

# %% [markdown]
# ### Second step: computation of the ratio between the two images <sup>99m</sup>Tc-sestamibi and 123 iodine

# %%
# Sum of all counts received for the first tracer (99mTc-sestamibi)
# Cumsum function returns the cumulative sum of the elements along a given axis
para_t1_sum=para_t1.cumsum()[-1]
# and for the second tracer (123 I)
para_t2_sum=para_t2.cumsum()[-1]
# Ratio
para_t1t2_ratio=para_t1_sum/para_t2_sum
print(para_t1_sum,para_t2_sum,para_t1t2_ratio)
# Out:
# 230815 66799 3.455366098294885

# %% [markdown]
# ### Third step: computation of subtraction image (<sup>99m</sup>Tc-sestamibi - 123 Iodine)

# %%
# Computation of subtraction image (99mTc-sestamibi - 123 Iodine)
# * 100 allows working with floats
substract=100*para_t1-100*para_t1t2_ratio*para_t2

plt.subplots(1,2,figsize=(10,5))
plt.subplot(1,2,1)
plt.imshow(substract,vmin=0,vmax=5000,aspect='auto')
plt.savefig('mibi2.png', dpi=300)
plt.subplot(1,2,2)
plt.hist(substract.flatten(),256,[0,5000]); plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>
